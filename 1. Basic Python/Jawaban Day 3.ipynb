# %% [markdown]
# <h2>Quiz 1 : Helper Function</h2>
#
# Jawab Pertanyaan di bawah ini :
#
# Misalkan kamu ingin mengetahui tentang kegunaan fungsi 'len' di Python, maka fungsi apa yang bisa kamu gunakan untuk menolong kamu?

# %%
# lengkapi code ini
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# <h2>Quiz 2 : Built-in Function</h2>
#
# Jawab Pertanyaan di bawah ini :
#
# Apa itu built-in Function?
#
# Sebutkan 3 built-in Function di pyhon!
#
# Berikan contoh masing2 1 cara penggunaan built-in function yang kamu sebutkan sebelumnya

# %% [markdown]
# * Fungsi build in merupakan fungsi yang telah tersedia pada python saat pertama kali terinstall
# * help(), len(), print()

# %%
# Contoh penggunaan built in function
print('hello world')
help(print())
# Out:
# hello world
#
# Help on NoneType object:
#
# class NoneType(object)
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
len('inistring')
# Out:
# 9

# %% [markdown]
# <h2>Quiz 3 : Method dan Function</h2>
#
# Jawab Pertanyaan di bawah ini :
#
# - Apa perbedaan method dan function?

# %% [markdown]
# method dan function merupakan hal yang sama, hanya beberapa orang sering memanggilnya dengan nama yang berbeda beda

# %% [markdown]
# <h2>Quiz 4 : Menggunkan Method String</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
kalimat = "Corona cepat selesai"

# gunakan method untuk mengubah nilai kalimat menjadi uppercase semua kemudian tampilkan hasilnya
print(kalimat.upper())

# gunakan method untuk menghitung berapa huruf e di dalam kalimat
print(kalimat.count('e'))
# Out:
# CORONA CEPAT SELESAI
# 3

# %% [markdown]
# Expected Output :
#
# CORONA CEPAT SELESAI
#
# 3

# %% [markdown]
# <h2>Quiz 5 : Menggunkan Method List</h2>
#
# Lengkapi kode untuk menghasilkan suatu output yang di harapkan

# %%
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# gunakan suatu method dari object list untuk menampilkan index dari nilai 20
for i, x in enumerate(areas):
    if x == 20:
        print(i)

# gunakan suatu method dari object list untuk menambahkan nilai 15.5 kedalam list ke index terakhirnya
areas.append(15.5)
print(areas)
# Out:
# 2
# [11.25, 18.0, 20.0, 10.75, 9.5, 15.5]

# %% [markdown]
# Expected Output :
#
# 2
#
# [11.25, 18.0, 20.0, 10.75, 9.50, 15.5]

# %% [markdown]
# <h2>Quiz 6 : Membuat Simple Function</h2>
#
# Buatlah suatu fungsi yang menerima satu input argumen berbentuk list dan mempunyai elemen bertipe numeric semua, dimana fungsi tersebut berguna untuk menghitung rata2 dari kumpulan elemen list tersebut. namai fungsi tersebut 'mean_list'

# %%
obj_list = [11.25, 18.0, 20.0, 10.75, 9.50]
def mean_list(inp_list):
    # isikan code    
    temp = 0
    for i in inp_list:
        temp = temp + i
    return temp/len(inp_list)
    
print(mean_list(obj_list))
# Out:
# 13.9

# %% [markdown]
# Expected Output :
#
# 13.9

# %% [markdown]
# <h2>Quiz 7 : Membuat Function dengan Multiple arguments</h2>
#
# Buatlah suatu fungsi untuk melakukan penggabungan antara dua list

# %%
obj_list = [2, 4, 5, 6]
obj_pengali = [1, 2, 3]
def kali_list(obj_list, obj_pengali):
    # isikan kode
    return obj_list+obj_pengali
    
print(kali_list(obj_list, obj_pengali))
# Out:
# [2, 4, 5, 6, 1, 2, 3]

# %% [markdown]
# Expected Output :
#
# [2, 4, 5, 6, 1, 2, 3]
