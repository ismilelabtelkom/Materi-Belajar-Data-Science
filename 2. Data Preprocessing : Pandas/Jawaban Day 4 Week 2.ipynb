# %% [markdown]
# <b>Note</b> : Pada kuis kali ini kita akan menggunakan data diamonds.csv yang bisa kalian download disini. setelah di download, kalian pindahkan data tersebut satu level dengan direktori file notebook ini.

# %%
import pandas as pd
df = pd.read_csv('diamonds-1.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# Columns Metadata :
#
# carat : berat diamond
#
# cut : kualitas diamond
#
# color : warna diamond
#
# clarity : level kemurnian diamonds
#
# depth : tinggi dari diamond tabel
#
# table : lebar  dari diamond tabel
#
# price : harga diamond ($US)
#
# x : panjang
#
# y : lebar
#
# z : kedalaaman

# %% [markdown]
# <h2>Quiz 1 : Process Grouping</h2>
#
# Jelaskan prosess yang terjadi dalam grouping data menggungkan method <b>groupby()</b> dari pandas.

# %% [markdown]
# * Splitting: memisahkan data kedalam suatu groub berdasarkan kriteria tertentu
# * Applying: melakukan suatu operasi terhadap sekumpulan data di group group tersebut
# * Combining: menggabungkan data menjadi suatu struktur baru

# %% [markdown]
# <h2>Quiz 2 : Grouping All Column</h2>
#
# Group data diamond berdasarkan cut (kualitas), lakukan aggregasi dengan fungsi rata2.
#
# Kemudian jawab pertanyaan berikut.
# - Berapa harga rata2 dari diamond berkualitas Premium

# %%
# code here
df.groupby('cut').mean()
# Out:
#               carat      depth      table        price         x         y  \
# cut
# Fair       1.046137  64.041677  59.053789  4358.757764  6.246894  6.182652
# Good       0.849185  62.365879  58.694639  3928.864452  5.838785  5.850744
# Ideal      0.702837  61.709401  55.951668  3457.541970  5.507451  5.520080
# Premium    0.891955  61.264673  58.746095  4584.257704  5.973887  5.944879
# Very Good  0.806381  61.818275  57.956150  3981.759891  5.740696  5.770026
#
#                   z
# cut
# Fair       3.982770
# Good       3.639507
# Ideal      3.401448
# Premium    3.647124
# Very Good  3.559801

# %% [markdown]
# jawaban:
# * Harga rata-rata dari diamond berkualitas premium adalah 4584.257704

# %% [markdown]
# Expected Output :
#
# ![title](image/day4-expected-output2.png)

# %% [markdown]
# <h2>Quiz 3 : Grouping Some Column base on Multiple Criteria</h2>
#
# Lakukan groupby pada data berdasarkan kriteria cut(kualitas) dan color (warna) secara berurutan, dengan aggregasi pada column carat, table, dan price saja. dengan fungsi agregasi rata-rata.
#
# Kemudian jawab pertanyaan berikut :
# - Berapa harga diamond yang berkriteria premium dan berwarna J
# - Berapa nilai dari carat diamond yang berkriteria very good dan berwarna H

# %% [markdown]
# Expected Output :
#
# Note : gambar hanya sebagaian dari keseluruhan data

# %%
# code here
df.groupby(by=['cut','color'])['carat','table','price'].mean()
# Out:
#                     carat      table        price
# cut       color
# Fair      D      0.920123  58.969325  4291.061350
#           E      0.856607  59.364732  3682.312500
#           F      0.904712  59.453205  3827.003205
#           G      1.023822  58.773248  4239.254777
#           H      1.219175  58.696370  5135.683168
#           I      1.198057  59.237143  4685.445714
#           J      1.341176  58.917647  4975.655462
# Good      D      0.744517  58.541541  3405.382175
#           E      0.745134  58.779957  3423.644159
#           F      0.775930  58.910891  3495.750275
#           G      0.850896  58.471986  4123.482204
#           H      0.914729  58.611111  4276.254986
#           I      1.057222  58.773946  5078.532567
#           J      1.099544  58.813029  4574.172638
# Ideal     D      0.565766  55.965632  2629.094566
#           E      0.578401  55.967461  2597.550090
#           F      0.655829  55.924203  3374.939362
#           G      0.700715  55.902375  3720.706388
#           H      0.799525  55.965843  3889.334831
#           I      0.913029  56.021357  4451.970377
#           J      1.063594  56.012612  4918.186384
# Premium   D      0.721547  58.718964  3631.292576
#           E      0.717745  58.779461  3538.914420
#           F      0.827036  58.679279  4324.890176
#           G      0.841488  58.702360  4500.742134
#           H      1.016449  58.792034  5216.706780
#           I      1.144937  58.771849  5946.180672
#           J      1.293094  58.874752  6294.591584
# Very Good D      0.696424  58.041309  3470.467284
#           E      0.676317  58.038875  3214.652083
#           F      0.740961  57.848429  3778.820240
#           G      0.766799  57.784428  3872.753806
#           H      0.915948  57.903015  4535.390351
#           I      1.046952  58.105150  5255.879568
#           J      1.133215  58.277729  5103.513274

# %% [markdown]
# jawaban:
# - Berapa harga diamond yang berkriteria premium dan berwarna J: 6294.591584
# - Berapa nilai dari carat diamond yang berkriteria very good dan berwarna H: 0.915948

# %% [markdown]
# Expected Output :
#
# ![title](image/day4-expected-output3.png)

# %% [markdown]
# <h2>Quiz 4 : Group By Multiple Aggregate Base on Multiple Criteria</h2>
#
# Lakukan groupby pada data berdasarkan kriteria cut(kualitas) dan color (warna) secara berurutan kemudian aggregasi objek group by nya dengan fungsi rata2 dan median.
#
# Kemudian Jawab Pertanyaan berikut :
#
# - Berapa nilai median dari harga diamond berkualitas good dan berwarna F

# %%
df.groupby(by=['cut','color']).agg({'mean','median'})
# Out:
#                  carat            depth             table              price  \
#                 median      mean median       mean median       mean  median
# cut       color
# Fair      D      0.900  0.920123   64.8  64.048466   58.0  58.969325  3730.0
#           E      0.900  0.856607   64.8  63.319643   59.0  59.364732  2956.0
#           F      0.900  0.904712   64.8  63.508013   59.0  59.453205  3035.0
#           G      0.980  1.023822   65.0  64.339809   58.0  58.773248  3057.0
#           H      1.010  1.219175   65.1  64.585149   58.0  58.696370  3816.0
#           I      1.010  1.198057   65.1  64.220571   58.0  59.237143  3246.0
#           J      1.030  1.341176   65.0  64.357143   58.0  58.917647  3302.0
# Good      D      0.700  0.744517   63.4  62.365710   58.0  58.541541  2728.5
#           E      0.700  0.745134   63.3  62.203751   58.0  58.779957  2420.0
#           F      0.710  0.775930   63.2  62.202310   59.0  58.910891  2647.0
#           G      0.900  0.850896   63.4  62.526636   58.0  58.471986  3340.0
#           H      0.900  0.914729   63.4  62.499573   58.0  58.611111  3468.5
#           I      1.000  1.057222   63.5  62.475096   58.0  58.773946  3639.5
#           J      1.020  1.099544   63.4  62.395765   58.0  58.813029  3733.0
# Ideal     D      0.500  0.565766   61.8  61.678370   56.0  55.965632  1576.0
#           E      0.500  0.578401   61.8  61.686677   56.0  55.967461  1437.0
#           F      0.530  0.655829   61.8  61.675562   56.0  55.924203  1775.0
#           G      0.540  0.700715   61.8  61.700164   56.0  55.902375  1857.5
#           I      5946.180672  6.740  6.489531  6.690  6.453270  4.130
#           J      6294.591584  6.920  6.809975  6.900  6.770644  4.260
# Very Good D      3470.467284  5.460  5.501210  5.490  5.531613  3.360
#           E      3214.652083  5.330  5.432467  5.365  5.463213  3.280
#           F      3778.820240  5.690  5.610504  5.720  5.642717  3.530
#           G      3872.753806  5.680  5.660204  5.710  5.688752  3.540
#           H      4535.390351  6.130  5.982286  6.160  6.006272  3.830
#           I      5255.879568  6.350  6.272259  6.360  6.299028  3.935
#           J      5103.513274  6.560  6.460782  6.575  6.495074  4.060
#
#
#                      mean
# cut       color
# Fair      D      3.839877
#           E      3.722143
#           F      3.787821
#           G      3.963153
#           H      4.219373
#           I      4.193486
#           J      4.319664
# Good      D      3.504864
#           E      3.496066
#           F      3.544609
#           G      3.647922
#           H      3.726937
#           I      3.901513
#           J      3.977459
# Ideal     D      3.201800
#           E      3.220346
#           F      3.338732
#           G      3.403120
#           H      3.539917
#           I      3.695270
#           J      3.912757
# Premium   D      3.415926
#           E      3.408875
#           F      3.588391
#           G      3.579641
#           H      3.811699
#           I      3.963894
#           J      4.168020
# Very Good D      3.405089
#           E      3.373996
#           F      3.472902
#           G      3.509883
#           H      3.713849
#           I      3.890972
#           J      4.006873

# %% [markdown]
# * nilainya adalah 2647.0

# %% [markdown]
# Expected Output :
#
# Note : gambar hanya sebagaian dari keseluruhan data
#
# ![title](image/day4-expected-output4.png)

# %% [markdown]
# <h2>Quiz 5 : Group By With Different Aggregation for specific Column</h2>
#
# Lakukan groupby pada data berdasarkan criteria cut(kualitas), kemudian aggreagate dengan fungsi max pada column price dan fungsi min pada column carat.
#
# Kemudian Jawab Pertanyaan berikut :
#
# - Berapa nilai max dari price untuk diamond berkualitas Ideal

# %% [markdown]
# Expected Output :
#
# ![title](image/day4-expected-output5.png)

# %%
# code here
df.groupby('cut')['price','carat'].agg({'price' : 'max','carat': 'min'})
# Out:
#            price  carat
# cut
# Fair       18574   0.22
# Good       18788   0.23
# Ideal      18806   0.20
# Premium    18823   0.20
# Very Good  18818   0.20

# %% [markdown]
# * nilai maxnya adalah 18806

# %% [markdown]
# <h2>Quiz 6 : Group By With Custom Function</h2>
#
# Lakukan groupby pada data berdasarkan criteria cut(kualitas), kemudian lakukan aggregasi dengan fungsi standarisasi pada column carat dan fungsi rentang nilai antara max dan min pada column price.
#
# Kemudian jawab pertanyaan berikut :
# - Berapa selisih harga tertinggi dan terendah dari diamond berkualitas Premium

# %% [markdown]
# Expected Output :
#
# ![title](image/day4-expected-output6.png)

# %%
df_new = df.groupby('cut').agg({'carat': 'std', 'price' : ['min','max']})
df_new['selisih_price'] = df_new['price']['max'] - df_new['price']['min']
df_new
# Out:
#               carat price        selisih_price
#                 std   min    max
# cut
# Fair       0.516404   337  18574         18237
# Good       0.454054   327  18788         18461
# Ideal      0.432876   326  18806         18480
# Premium    0.515262   326  18823         18497
# Very Good  0.459435   336  18818         18482

# %% [markdown]
# jawaban:
# * jawabannya adalah 18497
