# %% [markdown]
# <h2>Tugas Harian No 1 : Pemahaman Component Matplotlib</h2>
#
# - Jelaskan apa itu Figure
# - Jelaskan apa itu Axis

# %% [markdown]
# * Figure: windows / pagi / halaman dari objek visual, contoh sederhananya apabila kita menggambar di kertas, maka kertas tersebut merupakan figure dari gambar kita
#
# * Axis: area pada figure dimana data akan diplot, axis terdapat berbagai macam komponen seperti x-asis, y-axis, dan lain sebagainya

# %% [markdown]
# <h2>Tugas Harian No 2 : Membuat Component Figure dan Axis</h2>
#
# - Buatlah Figure dan Axis kosong tanpa Data
# - Plot data di bawah ini dengan 2 cara, yaitu dengan membuat figure dan axis secara explicit dan Implicit

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 20, 100)
y = np.cos(x/2)

# %%
fig = plt.figure(figsize=[5,5])

ax = fig.add_subplot()
plt.show()

# %% [markdown]
# Exected Output :
# ![title](image/day1-no2.png)

# %%
fig = plt.figure()
ax  = fig.add_subplot()
ax.plot(x,y)
plt.show()

# %% [markdown]
# Expected Output :
#
# ![title](image/day1-no2-2.png)

# %% [markdown]
# <h2>Tugas Harian No 3 : Memasukan multiple data ke dalam satu axis</h2>
#
# - Plot ketiga data berikut ke dalam satu axis, dan gunakan seaborn style
# - save data tersebut dengan nama file bebas

# %%
x = np.linspace(0, 20, 100)
y = np.cos(x/2)
y2 = np.sin(x)
y3 = np.sin(2*x)

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots()
ax.plot(x,y)
ax.plot(x,y2)
ax.plot(x,y3)
plt.show()

# %% [markdown]
# Expected Output :
#
# ![title](image/day1-no3.png)
